# %% [markdown]
# ## 【問題1】学習・推定

# %% [markdown]
# #### Google colabで実行

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
mkdir .kaggle

# %%
ls -a
# Out:
# ./  ../  .config/  drive/  .kaggle/  sample_data/

# %%
import json

token = {"username":"satomitsukagoshi","key":"0310bf6ab699a23cea95c72a16dd3731"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 /content/.kaggle/kaggle.json

# %%
pwd
# Out:
# '/content'

# %%
ls -a .kaggle
# Out:
# ./  ../  kaggle.json

# %%
# !cp /content/.kaggle/kaggle.json /root/.kaggle/kaggle.json

# %% [markdown]
# 囮

# %%
# !kaggle competitions download -c tgs-salt-identification-challenge
# Out:
# ...
# 100% 37.9M/37.9M [00:01<00:00, 16.3MB/s]
#
# ...
#   0% 0.00/264k [00:00<?, ?B/s]
# 100% 264k/264k [00:00<00:00, 85.9MB/s]
# ...
#   0% 0.00/322k [00:00<?, ?B/s]
# 100% 322k/322k [00:00<00:00, 46.0MB/s]
# ...
#  94% 154M/163M [00:02<00:00, 41.0MB/s]
# 100% 163M/163M [00:02<00:00, 62.9MB/s]
# ...
#  46% 19.0M/41.4M [00:00<00:00, 26.8MB/s]
# 100% 41.4M/41.4M [00:00<00:00, 93.3MB/s]
# ...
#  98% 213M/217M [00:04<00:00, 69.3MB/s]
# 100% 217M/217M [00:04<00:00, 55.5MB/s]
# ...
#   0% 0.00/922k [00:00<?, ?B/s]
# 100% 922k/922k [00:00<00:00, 51.1MB/s]

# %%
# !git clone https://github.com/zhixuhao/unet.git
# Out:
# Cloning into 'unet'...
# remote: Enumerating objects: 394, done.
# remote: Total 394 (delta 0), reused 0 (delta 0), pack-reused 394
# Receiving objects: 100% (394/394), 44.92 MiB | 21.18 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %%
# !unzip /content/test.zip  -d Salt
# Out:
# Archive:  /content/test.zip
#    creating: Salt/images/
#   inflating: Salt/images/8cf16aa0f5.png
#   inflating: Salt/images/23012be6b7.png
#   inflating: Salt/images/9e46a3352e.png
#   inflating: Salt/images/8016056c46.png
#   inflating: Salt/images/a490a68472.png
#   inflating: Salt/images/cf19041b8e.png
#   inflating: Salt/images/a5c02f60cd.png
#   inflating: Salt/images/631cec82b9.png
#   inflating: Salt/images/bffa15aaa5.png
#   inflating: Salt/images/31e17c9459.png
#   inflating: Salt/images/b695427db8.png
#   inflating: Salt/images/57b062d234.png
#   inflating: Salt/images/1705ade299.png
#   inflating: Salt/images/f1a3d6352e.png
#   inflating: Salt/images/99e331e803.png
#   inflating: Salt/images/d343f6974e.png
#   inflating: Salt/images/068f7a5267.png
#   inflating: Salt/images/d4c235a41e.png
#   inflating: Salt/images/bf56f7dd40.png
#   inflating: Salt/images/6b8b1e7ad6.png
#   inflating: Salt/images/c268afb4a1.png
#   inflating: Salt/images/63ed0faeb8.png
# ...

# %%
import os
os.chdir('/content/unet/')

# %%
pwd
# Out:
# '/content/unet'

# %%
# !python main.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !unzip /content/train.zip  -d Salt_train_real
# Out:
# Archive:  /content/train.zip
#    creating: Salt_train_real/images/
#    creating: Salt_train_real/masks/
#   inflating: Salt_train_real/images/8d08955cdf.png
#   inflating: Salt_train_real/images/e045664b46.png
#   inflating: Salt_train_real/images/4989c6509e.png
#   inflating: Salt_train_real/images/fff4eb4941.png
#   inflating: Salt_train_real/images/3a310860a3.png
#   inflating: Salt_train_real/images/7a696bb878.png
#   inflating: Salt_train_real/images/8d3ee9356b.png
#   inflating: Salt_train_real/images/213e0a9f7b.png
#   inflating: Salt_train_real/images/78f17697f2.png
#   inflating: Salt_train_real/images/bd20d18369.png
#   inflating: Salt_train_real/images/de08c5a3b7.png
#   inflating: Salt_train_real/images/f06ef6c8b7.png
#   inflating: Salt_train_real/images/b2d02516e1.png
#   inflating: Salt_train_real/images/5edb37f5a8.png
#   inflating: Salt_train_real/images/b1f0e104f5.png
#   inflating: Salt_train_real/images/40e8e14e60.png
# ...

# %%
# !python c_main.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %% [markdown]
# #### 動いた。Predict結果(学習を一日回さないと綺麗に出ないとのこと)

# %%
from IPython.display import display
from PIL import Image
Pred = "0_predict.png"
display(Image.open(Pred))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x119C3F240>

# %% [markdown]
# ## 【問題2】コードリーディング

# %% [markdown]
# main.pyが実行全体のプログラム。データの読み込み、modelのTrain,Testを実行
# data.pyでフォルダからの画像データの読み込み、シェイプの修正、セグメンテーションした結果の画像ファイルを出力
# model.pyでkerasを利用したUnetのネットワークを構築している
